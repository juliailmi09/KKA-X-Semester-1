# %% [markdown]
# <a href="https://colab.research.google.com/github/juliailmi09/KKA-X-Semester-1/blob/main/2_type_variabel_julia_sanggar_ilmi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Julia Sanggar Ilmi
#
# Kelas: X. 11
#
# No. absen: 16

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("ghinaanam.2025@gmail.com")
print("ghinaanam.2025@gmail.com")
print("ghinaanam.2025@gmail.com")
# Out:
# ghinaanam.2025@gmail.com
# ghinaanam.2025@gmail.com
# ghinaanam.2025@gmail.com

# %%
email_user_1 = "ghinaanam.2025@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1517945494.py in <cell line: 0>()
#       1 email_user_1 = "ghinaanam.2025@gmail.com"
#       2
# ----> 3 print(email_user_1)
#       4 print(email_user_1)
#       5 print(email_user_1)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #Peraturan Penamaan Variabel

# %%
#Hanya diperbolehkan menggunakan huruf, angka, dan underscore
email_user_2 = "bobbyaliando@gmail.com"
print (email_user_2)
# Out:
# bobbyaliando@gmail.com

# %%
emailuser2 = "bobbyaliando@gmail.com"

print(emailuser2)
# Out:
# bobbyaliando@gmail.com

# %%
#Tidak boleh didahului angka
3_email_user = "willytaulany@gmail.com"

print(3_email_user)
# Out:
#   File "/tmp/ipython-input-4198172721.py", line 2
#     3_email_user = "willytaulany@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
email_user_3 = "willytaulany@gmail.com"

print(email_user_3)
# Out:
# willytaulany@gmail.com

# %%
#Tidak boleh menggunakan kata kunci python
for = "HimamHimawan@gmail.com"
# Out:
#   File "/tmp/ipython-input-3021037871.py", line 2
#     for = "HimamHimawan@gmail.com"
#         ^
# SyntaxError: invalid syntax

# %%
For = "HimamHimawan@gmail.com"

print(For)
# Out:
# HimamHimawan@gmail.com

# %%
print = "Juliawati@gmail.com"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1948412904.py in <cell line: 0>()
#       1 print = "Juliawati@gmail.com"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Juliawati@gmail.com"

print(Print)
# Out:
# Juliawati@gmail.com

# %%
#tidak eror tapi dianjurkan harus deskriptif
_ = "Devandraarnoldi@gmail.com"

# %%
print(_)
# Out:
# Devandraarnoldi@gmail.com

# %%
_ = "haidarhalilintar@gmail.com"

# %%
print(_)
# Out:
# haidarhalilintar@gmail.com

# %% [markdown]
# #Assigment

# %%
#Single assigment
nama_mahasiswa_1 = "Alexandrio"

print(nama_mahasiswa_1)
# Out:
# Alexandrio

# %%
#Multiple Assignment

# nama_barang_1 = "rinso"
# nama_barang_2 = "molto"

nama_barang_1, nama_barang_2 = "rinso", "molto"

print(nama_barang_1)
print(nama_barang_2)
# Out:
# rinso
# molto

# %%
#Assignment yang sama
nilai_devandra = nilai_willy = nilai_dzakki = 100

print(nilai_devandra)
print(nilai_willy)
print(nilai_dzakki)
# Out:
# 100
# 100
# 100

# %%
#Menimpa/Mengubah Nilai Variabel

nilai_himam = 95

# %%
print(nilai_himam)
# Out:
# 95

# %%
nilai_himam = 100

# %%
print(nilai_himam)
# Out:
# 100

# %% [markdown]
# #Penggunaan Operator di Python

# %%
#Tanpa Variabel
print(20+3)
# Out:
# 23

# %%
#Operand disimpan ke dalam variabel
roti_swiss_alex = 20
roti_swiss_nazril = 3

print(roti_swiss_alex + roti_swiss_nazril)
# Out:
# 23

# %%
#Hasil operasi disimpan ke dalam variabel
jumlah_roti_swiss = 20+3

print(jumlah_roti_swiss)
# Out:
# 23

# %%
#soal no. 1 (Tanpa variabel)
print(24 * 3)
# Out:
# 72

# %%
#soal no. 2 (Hasil operasi disimpan ke dalam variabel)
Total_jumlah_botol = 24 * 3

# %%
#soal no. 3 (Operand disimpan kedalam variabel)
Banyak_botol_per_kardus = 24
Jumlah_kardus = 3

print(Banyak_botol_per_kardus * Jumlah_kardus)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-565314119.py in <cell line: 0>()
#       3 Jumlah_kardus = 3
#       4
# ----> 5 print(Banyak_botol_per_kardus * Jumlah_kardus)
#
# TypeError: 'str' object is not callable

# %%
#soal no. 4

# %% [markdown]
# #Operator Aritmatika

# %%
buku_tulis_himam = 55
buku_tulis_vico = 15

# %%
#Penjumlahan
total_buku_tulis = buku_tulis_himam + buku_tulis_vico
print(total_buku_tulis)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1372575723.py in <cell line: 0>()
#       1 #Penjumlahan
#       2 total_buku_tulis = buku_tulis_himam + buku_tulis_vico
# ----> 3 print(total_buku_tulis)
#
# TypeError: 'str' object is not callable

# %%
#Pengurangan

selisi_buku_tulis = buku_tulis_himam - buku_tulis_vico
print(selisi_buku_tulis)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1650202698.py in <cell line: 0>()
#       2
#       3 selisi_buku_tulis = buku_tulis_himam - buku_tulis_vico
# ----> 4 print(selisi_buku_tulis)
#
# TypeError: 'str' object is not callable

# %%
#Perkalian
jumlah_kardus_buku_tulis = 3
isi_buku_tulis_perkardus = 10

total_buku_tulis = jumlah_kardus_buku_tulis * isi_buku_tulis_perkardus

print(total_buku_tulis)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2707565551.py in <cell line: 0>()
#       5 total_buku_tulis = jumlah_kardus_buku_tulis * isi_buku_tulis_perkardus
#       6
# ----> 7 print(total_buku_tulis)
#
# TypeError: 'str' object is not callable

# %%
#Pembagian
jumlah_anak_yatim = 9

jumlah_buku_tulis_tiap_anak = total_buku_tulis / jumlah_anak_yatim
print(jumlah_buku_tulis_tiap_anak)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1227822645.py in <cell line: 0>()
#       3
#       4 jumlah_buku_tulis_tiap_anak = total_buku_tulis / jumlah_anak_yatim
# ----> 5 print(jumlah_buku_tulis_tiap_anak)
#
# TypeError: 'str' object is not callable

# %%
#Pembagian bulat
jumlah_anak_yatim = 9

jumlah_buku_tulis_tiap_anak = total_buku_tulis // jumlah_anak_yatim
print(jumlah_buku_tulis_tiap_anak)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-348654593.py in <cell line: 0>()
#       3
#       4 jumlah_buku_tulis_tiap_anak = total_buku_tulis // jumlah_anak_yatim
# ----> 5 print(jumlah_buku_tulis_tiap_anak)
#
# TypeError: 'str' object is not callable

# %%
#Sisa bagi

sisa_buku_tulis = total_buku_tulis % jumlah_anak_yatim
print(sisa_buku_tulis)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1758443345.py in <cell line: 0>()
#       2
#       3 sisa_buku_tulis = total_buku_tulis % jumlah_anak_yatim
# ----> 4 print(sisa_buku_tulis)
#
# TypeError: 'str' object is not callable

# %%
#Perpangkatan

sisi = 5
luas_persegi = sisi ** 2

print(luas_persegi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-783319294.py in <cell line: 0>()
#       4 luas_persegi = sisi ** 2
#       5
# ----> 6 print(luas_persegi)
#
# TypeError: 'str' object is not callable

# %%
luas_persegi = 36

sisi = luas_persegi ** (1/2)
print(sisi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-625735060.py in <cell line: 0>()
#       2
#       3 sisi = luas_persegi ** (1/2)
# ----> 4 print(sisi)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# Latihan Soal

# %%
#soal no. 1 (Penjumlahan)

apel_dina = 8
apel_ibu_dina = 5
total_apel = apel_dina + apel_ibu_dina

print(total_apel)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-21139913.py in <cell line: 0>()
#       5 total_apel = apel_dina + apel_ibu_dina
#       6
# ----> 7 print(total_apel)
#
# TypeError: 'str' object is not callable

# %%
#soal no. 2 (Pengurangan)

mangga_1 = 30
mangga_2 = 12

total_mangga = mangga_1 - mangga_2
print(total_mangga)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1992830819.py in <cell line: 0>()
#       5
#       6 total_mangga = mangga_1 - mangga_2
# ----> 7 print(total_mangga)
#
# TypeError: 'str' object is not callable

# %%
#soal no. 3 (Perkalian)

meja_kelas = 6
meja_1 = 4

total_jumlah_siswa = meja_kelas * meja_1
print(total_jumlah_siswa)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2646986384.py in <cell line: 0>()
#       5
#       6 total_jumlah_siswa = meja_kelas * meja_1
# ----> 7 print(total_jumlah_siswa)
#
# TypeError: 'str' object is not callable

# %%
soal no. 4 (Pembagian)

jumlah_jeruk = 28
jumlah_keranjang = 7

jumlah_jeruk_setiap_keranjang = jumlah_jeruk  /  jumlah_keranjang
print(jumlah_jeruk_setiap_keranjang)
# Out:
#   File "/tmp/ipython-input-221757886.py", line 1
#     soal no. 4 (Pembagian)
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# #Tipe Variabel

# %%
usia = 8

print(usia)
type(usia)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3945576540.py in <cell line: 0>()
#       1 usia = 8
#       2
# ----> 3 print(usia)
#       4 type(usia)
#
# TypeError: 'str' object is not callable

# %%
berat_badan = 72.5

type(berat_badan)
# Out:
# float

# %%
lulus = True

type(lulus)
# Out:
# bool

# %%
titik_koordinat = -5
type(titik_koordinat)
# Out:
# int

# %%
titik_koordinat_bintang = -10.0
type(titik_koordinat_bintang)
# Out:
# float

# %% [markdown]
# #Konversi Tipe Data

# %%
usia = 7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = float(usia)
print(usia)
type(usia)
# Out:
# 7.0
# float

# %%
berat_badan = 72.5
print(berat_badan)
type(berat_badan)
# Out:
# 72.5
# float

# %%
berat_badan = int(berat_badan)
print(berat_badan)
type(berat_badan)
# Out:
# 72
# int

# %%
usia = 7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = str(usia)
print(usia)
type(usia)
# Out:
# 7
# str

# %%
lulus = 1
print(lulus)
type(lulus)
# Out:
# 1
# int

# %%
lulus = bool(lulus)
print(lulus)
type(lulus)
# Out:
# True
# bool

# %%
lulus = 0
print(lulus)
type(lulus)
# Out:
# 0
# int

# %%
lulus = bool(lulus)
print(lulus)
type(lulus)
# Out:
# False
# bool
