# %% [markdown]
# <a href="https://colab.research.google.com/github/juliailmi09/KKA-X-Semester-1/blob/main/1_fungsi_print_julia_X_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Julia Sanggar Ilmi
#
# Kelas:X.11
#
# No Absen:16

# %%
print("Julia Sanggar Ilmi")
# Out:
# Julia Sanggar Ilmi

# %%
nama_saudara = "Oktavia nadhera fazila"

print(nama_saudara)
# Out:
# Oktavia nadhera fazila

# %%
jumlah_saudara = 2

print(jumlah_saudara)
# Out:
# 2

# %% [markdown]
# Menampilkan teks Bebas dan Nilai Variabel

# %%
print("saya mempunyai saudara sebanyak",jumlah_saudara,"nama saudara saya adalah",nama_saudara)
# Out:
# saya mempunyai saudara sebanyak 2 nama saudara saya adalah Oktavia nadhera fazila

# %% [markdown]
# Menampilkan Teks Bebas dan Variabel Menggunakan Tanda plus

# %%
print("saya memiliki saudara sebanyak"+str(jumlah_saudara) +"."+"nama saudara saya adalah"+ nama_saudara+".")
# Out:
# saya memiliki saudara sebanyak2.nama saudara saya adalahOktavia nadhera fazila.

# %% [markdown]
# Menampilkan Teks Bebas dan Nilai Variabel Menggunakan f String

# %%
print(f"Saya memiliki saudara sebanyak {jumlah_saudara}. Nama saudara saya adalah {nama_saudara}.")
# Out:
# Saya memiliki saudara sebanyak 2. Nama saudara saya adalah Oktavia nadhera fazila.

# %% [markdown]
# Escape Character

# %%
print("nama: Julia Sanggar Ilmi")
print("kelas: X-11")
print("no. Absen: 16")
# Out:
# nama: Julia Sanggar Ilmi
# kelas: X-11
# no. Absen: 16

# %%
print("nama: Julia Sanggar Ilmi\nkelas: X-11\nno. Absen: 16")
# Out:
# nama: Julia Sanggar Ilmi
# kelas: X-11
# no. Absen: 16

# %%
print("""nama\t\t: Julia Sanggar Ilmi
Kelas\t\t: X-11
No. Absen\t: 16""")
# Out:
# nama		: Julia Sanggar Ilmi
# Kelas		: X-11
# No. Absen	: 16

# %%
print("Julia Sanggar Ilmi")
# Out:
# Julia Sanggar Ilmi

# %%
print('Julia Sanggar Ilmi')
# Out:
# Julia Sanggar Ilmi

# %%
print('Habib Ja\'far')
# Out:
# Habib Ja'far

# %%
print("Habib Ja'far")
# Out:
# Habib Ja'far

# %%
print('Bu Shinta berkata,"Harap fokus menyimak!".')
# Out:
# Bu Shinta berkata,"Harap fokus menyimak!".

# %%
print("Bu Shinta berkata,\"Harap fokus menyimak!\".")
# Out:
# Bu Shinta berkata,"Harap fokus menyimak!".

# %%
print("Lokasi penyimpanan tugas KKA di D:\\MAN Demak\\KKA\\Tugas")
# Out:
# Lokasi penyimpanan tugas KKA di D:\MAN Demak\KKA\Tugas

# %% [markdown]
# Fungsi Parameter

# %%
nama_siswa_1 = "Daffanes"
nama_siswa_2 = "Adzka"
nama_siswa_3 = "Haidar"

print(nama_siswa_1, nama_siswa_2, sep="-")
# Out:
# Daffanes-Adzka

# %%
print(nama_siswa_3, nama_siswa_2, nama_siswa_1, nama_siswa_2, sep="*")
# Out:
# Haidar*Adzka*Daffanes*Adzka

# %%
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# Daffanes
# Adzka

# %%
print(nama_siswa_1, nama_siswa_2)
# Out:
# Daffanes Adzka

# %%
print(nama_siswa_1, end="-")
print(nama_siswa_2)
# Out:
# Daffanes-Adzka

# %% [markdown]
# Latihan soal
# Gunakan parameter end untuk menampilman tulisan sebagai berikut
# Hidar#Adzka#Daffanes#Adzka

# %%
print(nama_siswa_3, end="-")
print(nama_siswa_2, end="-")
print(nama_siswa_1, end="-")
print(nama_siswa_2)
# Out:
# Haidar-Adzka-Daffanes-Adzka
